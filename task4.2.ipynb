# %%
import cv2

# %%
import matplotlib.pyplot as mp

# %%
import numpy as np

# %%
img1=cv2.imread("taj.jpeg")
img2=cv2.imread("eft.jpg")
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-9b6927834eef> in <module>
#       1 img1=cv2.imread("taj.jpeg")
#       2 img2=cv2.imread("eft.jpg")
# ----> 3 img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
#       4 img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-m8us58q4\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
mp.imshow(img1)

# %%
mp.imshow(img2)

# %%
img1_array = img1.copy()
img2_array = img2.copy()

# %%
img1_array_cropped = img1_array[50:800,200:1000]

# %%
img1_array_cropped.shape
# Out:
# (750, 800, 3)

# %%
mp.imshow(img1_array_cropped)
cv2.imwrite("img1.jpg ",img1_array_cropped)
# Out:
# True

# %%
img2_array_cropped = img2_array[50:800, 200:1000]
img2_array_cropped.shape
# Out:
# (750, 800, 3)

# %%
mp.imshow(img2_array_cropped)
cv2.imwrite("img2.jpg",img2_array_cropped)
# Out:
# True

# %%
img1[50:800 , 200:1000] = img2_array_cropped

# %%
mp.imshow(img1)

# %%
img2[50:800 , 200:1000] = img1_array_cropped

# %%
mp.imshow(img2)
